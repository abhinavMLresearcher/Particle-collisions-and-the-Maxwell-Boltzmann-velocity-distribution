# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavMLresearcher/Particle-collisions-and-the-Maxwell-Boltzmann-velocity-distribution/blob/main/Amit_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
amit ji hope for bestiiiii
# Out:
#   File "/tmp/ipykernel_14943/1557329643.py", line 1
#     amit ji hope for bestiiiii
#          ^
# SyntaxError: invalid syntax
